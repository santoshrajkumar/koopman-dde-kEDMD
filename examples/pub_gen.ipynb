# %% [markdown]
# ## Quick Demo : Publication Figures / Details

# %%
# %matplotlib inline

import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "examples" else Path.cwd()
sys.path.insert(0, str(ROOT))

from kedmd_dde.Utils import pub_gen

# %%
results = pub_gen.p_vary()
# Out:
# [kedmd_dde] device: cuda:0
# p = 10: h = 2.261e-01, Assumption 3: satisfied
# p = 50: h = 7.111e-02, Assumption 3: satisfied
# p = 100: h = 4.494e-02, Assumption 3: satisfied
# p = 500: h = 1.685e-02, Assumption 3: satisfied
# p = 1500: h = 6.996e-03, Assumption 3: satisfied
# saved: /home/santosh/Research/koopman-dde-kEDMD/figures/p_vary.pdf

# %%
results = pub_gen.rho_vary()
# Out:
# [kedmd_dde] device: cuda:0
# p = 500, h = 1.685e-02
#     rho   Assumption 3
#     0.9      satisfied
#     0.6      satisfied
#     0.3      satisfied
#     0.1      satisfied
# saved: /home/santosh/Research/koopman-dde-kEDMD/figures/rho_vary.pdf

# %%
results = pub_gen.m_vary()
# Out:
# [kedmd_dde] device: cuda:0
# M = 2, p = 1500, h_X = 5.535957e-03, Assumption 3: satisfied
# M = 3, p = 1938, h_X = 5.534512e-03, Assumption 3: satisfied
# M = 6, p = 2928, h_X = 5.533070e-03, Assumption 3: satisfied
# saved: /home/santosh/Research/koopman-dde-kEDMD/figures/scalar_M_vary.pdf

# %%
result = pub_gen.scalar_phase()
# Out:
# [kedmd_dde] device: cuda:0
# h = 4.494e-02, Assumption 3: ok (0 thin balls, rho_eff 9.314e-02)
# RMSE = 2.6443e-03  (0.39% of RMS(true), 2.53% of std(true))
# saved: /home/santosh/Research/koopman-dde-kEDMD/figures/scalar_phase_new.pdf

# %%
result = pub_gen.planar_phase()
# Out:
# [kedmd_dde] device: cuda:0
# h = 1.430e-01, kernel degree = 7, Assumption 3: ok (0 thin balls, rho_eff 6.000e-01)
#  component         RMSE     NRMSE
#        x_1   2.5258e-02    2.66%
#        x_2   1.6047e-01    6.53%
#       both   1.1487e-01    6.16%
# saved: /home/santosh/Research/koopman-dde-kEDMD/figures/planar_phase_new_x1.pdf
# saved: /home/santosh/Research/koopman-dde-kEDMD/figures/planar_phase_new_x2.pdf
